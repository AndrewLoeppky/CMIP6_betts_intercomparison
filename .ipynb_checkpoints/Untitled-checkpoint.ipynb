# %% [markdown]
# ## Useful Docs
#
# https://docs.google.com/document/d/1yUx6jr9EdedCOLd--CPdTfGDwEwzPpCF6p1jRmqx-0Q/edit#
#
# https://agupubs.onlinelibrary.wiley.com/doi/epdf/10.3894/JAMES.2009.1.4
#
# https://www.carbonbrief.org/cmip6-the-next-generation-of-climate-models-explained

# %%
import xarray as xr
import pooch
import pandas as pd
import fsspec
from pathlib import Path
import time
import numpy as np
import json
import cftime
import matplotlib.pyplot as plt
import netCDF4 as nc
from cftime import date2num


# Handy metpy tutorial working with xarray:
# https://unidata.github.io/MetPy/latest/tutorials/xarray_tutorial.html#sphx-glr-tutorials-xarray-tutorial-py
import metpy.calc as mpcalc
from metpy.cbook import get_test_data
from metpy.units import units
from metpy.plots import SkewT

# %%
# get all the data from google's datastore
odie = pooch.create(
    path="./.cache",
    base_url="https://storage.googleapis.com/cmip6/",
    registry={
        "pangeo-cmip6.csv": None
    },
)
file_path = odie.fetch("pangeo-cmip6.csv")
df_in = pd.read_csv(file_path)

# %%
# only want table id "piControl" or "historical"
df_expt = df_in[(df_in.experiment_id == "piControl") | (df_in.experiment_id == "historical")]

# %%
# we only want 3hr data or less
df_3hr = df_expt[(df_expt.table_id == "3hr") | (df_expt.table_id == "CF3hr")]
df_3hr
# Out:
#        activity_id       institution_id          source_id experiment_id  \
# 1687          CMIP            NOAA-GFDL          GFDL-ESM4     piControl
# 1688          CMIP            NOAA-GFDL          GFDL-ESM4     piControl
# 1689          CMIP            NOAA-GFDL          GFDL-ESM4     piControl
# 1720          CMIP            NOAA-GFDL          GFDL-ESM4     piControl
# 1748          CMIP            NOAA-GFDL          GFDL-ESM4     piControl
# ...            ...                  ...                ...           ...
# 492709        CMIP  EC-Earth-Consortium  EC-Earth3-AerChem    historical
# 503295        CMIP                 CMCC          CMCC-ESM2    historical
# 503296        CMIP                 CMCC          CMCC-ESM2    historical
# 503297        CMIP                 CMCC          CMCC-ESM2    historical
# 503298        CMIP                 CMCC          CMCC-ESM2    historical
#
#        member_id table_id variable_id grid_label  \
# 1687    r1i1p1f1      3hr         tas        gr1
# 1688    r1i1p1f1      3hr       mrsos        gr1
# 1689    r1i1p1f1      3hr        mrro        gr1
# 1720    r1i1p1f1      3hr       tslsi        gr1
# 1748    r1i1p1f1      3hr        huss        gr1
# ...          ...      ...         ...        ...
# 492709  r4i1p1f1      3hr         tas         gr
# 503295  r1i1p1f1      3hr         vas         gn
# 503296  r1i1p1f1      3hr         uas         gn
# 503297  r1i1p1f1      3hr         tas         gn
# 503298  r1i1p1f1      3hr        huss         gn
#
#                                                    zstore  dcpp_init_year  \
# 1687    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/piCo...             NaN
# 1688    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/piCo...             NaN
# 1689    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/piCo...             NaN
# 1720    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/piCo...             NaN
# 1748    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/piCo...             NaN
# ...                                                   ...             ...
# 492709  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 503295  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 503296  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 503297  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 503298  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
#
#          version
# 1687    20180701
# 1688    20180701
# 1689    20180701
# 1720    20180701
# 1748    20180701
# ...          ...
# 492709  20201214
# 503295  20210114
# 503296  20210114
# 503297  20210114
# 503298  20210114
#
# [721 rows x 11 columns]

# %%
models = df_3hr.groupby("source_id")

# %%
# variables required to create figure 10
fig10_vars = ['tas', 'mrsos', 'huss']

# which models are able to produce figure 10?
fig10_models = []

# %%
for model in models.groups.keys():
    the_model = models.get_group(model) #df_3hr[df_3hr.source_id == model]
    model_vars = list(the_model.variable_id)
    if all(i in model_vars for i in fig10_vars) == True:
        fig10_models.append(model)

# %%
#for model in models.groups.keys():
    #print(model)
fig10_models
# Out:
# ['GFDL-CM4', 'GFDL-ESM4']

# %%
grouped = correct_table.groupby("source_id")

# %%
my_model = grouped.get_group("GFDL-ESM4")
my_model
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 240972        CMIP      NOAA-GFDL  GFDL-ESM4    historical  r1i1p1f1      3hr
# 240973        CMIP      NOAA-GFDL  GFDL-ESM4    historical  r1i1p1f1      3hr
# 240974        CMIP      NOAA-GFDL  GFDL-ESM4    historical  r1i1p1f1      3hr
# 240975        CMIP      NOAA-GFDL  GFDL-ESM4    historical  r1i1p1f1      3hr
# 241030        CMIP      NOAA-GFDL  GFDL-ESM4    historical  r1i1p1f1      3hr
#
#        variable_id grid_label  \
# 240972         vas        gr1
# 240973         uas        gr1
# 240974         tas        gr1
# 240975        huss        gr1
# 241030          pr        gr1
#
#                                                    zstore  dcpp_init_year  \
# 240972  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 240973  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 240974  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 240975  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 241030  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
#
#          version
# 240972  20190726
# 240973  20190726
# 240974  20190726
# 240975  20190726
# 241030  20190726

# %%
a = list(my_model.variable_id)
print(all(i in a for i in ["vas", "huss"]))
# Out:
# True
