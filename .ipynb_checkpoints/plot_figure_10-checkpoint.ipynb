# %% [markdown]
# # Plot Figure 10

# %%
import xarray as xr
import pandas as pd
import numpy as np
import cftime
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import netCDF4 as nc
import os

# Handy metpy tutorial working with xarray:
# https://unidata.github.io/MetPy/latest/tutorials/xarray_tutorial.html#sphx-glr-tutorials-xarray-tutorial-py
import metpy.calc as mpcalc
from metpy.cbook import get_test_data
from metpy.units import units
from metpy.plots import SkewT

# %%
files = os.listdir("data/")
files
# Out:
# ['CNRM-CM6-1-historical.nc']

# %%
ps = 100000 * units.Pa # temporary hack, should interpolate pressure from daily timeseries

# %%
for data in files:
    data='EC-Earth3-historical.nc'
    # open the data and re-convert time to cftime so xarray is happy
    data_in = xr.open_dataset(f"data/{data}", engine="netcdf4", decode_times=False).metpy.quantify()
    data_in["time"] = cftime.num2date(data_in.time, "minutes since 0000-01-01 00:00:00", calendar="noleap", has_year_zero=True)
    print("loaded data")
    
    # use metpy to convert humidity field to dew point temp
    data_in["td"] = mpcalc.dewpoint_from_specific_humidity(ps, data_in.tas, data_in.huss)

    # compute the spatial average
    spatial_average = data_in.mean(dim=("lat", "lon"))
    print("calculated spatial average")

    # separate by soil moisture by rounding to nearest kg/m3 in top soil layer
    the_max = max(spatial_average.mrsos[np.isnan(spatial_average.mrsos.values) == False])
    the_min = min(spatial_average.mrsos[np.isnan(spatial_average.mrsos.values) == False])
    the_range =  the_max - the_min
    
    spatial_average["soil_moisture_grp"] = ((spatial_average.mrsos / (the_range / 6)).round() * (the_range / 6))[np.isnan(spatial_average.mrsos.values) == False]
    
    
    gbysoil = spatial_average.groupby(spatial_average.soil_moisture_grp)
    print('generated groupings')
    # calculate and plot the average diurnal cycle of lcl height
    fig, ax = plt.subplots()
    for key in gbysoil.groups.keys():
        # group by hour
        hourly_data = gbysoil[key].groupby(gbysoil[key].time.dt.hour).mean(dim="time")  

        # find and plot the lcl
        plcl, tlcl = mpcalc.lcl(ps, hourly_data.tas, hourly_data.td)
        plcl_hpa = plcl / 100
        # HERE should add an hour 24 to each line by copying hour 0

        if key == min(gbysoil.groups.keys()):
            plot_kwargs = {"color":"darkblue"}
        elif key == max(gbysoil.groups.keys()):
            plot_kwargs = {"color":"red"}
        else:
            plot_kwargs = {"color":"black", "linestyle":"--", "linewidth":0.8}

        ax.plot(hourly_data.hour, plcl_hpa[np.isnan(plcl) == False], **plot_kwargs)
        the_label = ax.annotate(f"{round(key)} kg/m$^3$", (24, plcl_hpa[-1]))

    # make the plot match Betts fig 11
    plt.gca().invert_yaxis()
    ax.set_xlabel("UTC")
    ax.set_ylabel("P$_{LCL}$ (hPa)")
    #ax.axvline(21, color="k", linewidth=1)
    ax.xaxis.set_major_locator(MultipleLocator(6))
    ax.xaxis.set_major_formatter('{x:.0f}')
    ax.xaxis.set_minor_locator(MultipleLocator(1))
    ax.set_xticks((0,6,12,18,24))
    ax.set_xlim(0,28)
    ax.set_title(data[:-3]);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     198 try:
# --> 199     file = self._cache[self._key]
#     200 except KeyError:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/lru_cache.py:53, in LRUCache.__getitem__(self, key)
#      52 with self._lock:
# ---> 53     value = self._cache[key]
#      54     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/jovyan/work/data_share/andrew/data/EC-Earth3-historical.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
#       2 data='EC-Earth3-historical.nc'
#       3 # open the data and re-convert time to cftime so xarray is happy
# ----> 4 data_in = xr.open_dataset(f"data/{data}", engine="netcdf4", decode_times=False).metpy.quantify()
#       5 data_in["time"] = cftime.num2date(data_in.time, "minutes since 0000-01-01 00:00:00", calendar="noleap", has_year_zero=True)
#       6 print("loaded data")
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/api.py:495, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     483 decoders = _resolve_decoders_kwargs(
#     484     decode_cf,
#     485     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     491     decode_coords=decode_coords,
#     492 )
#     494 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 495 backend_ds = backend.open_dataset(
#     496     filename_or_obj,
#     497     drop_variables=drop_variables,
#     498     **decoders,
#     499     **kwargs,
#     500 )
#     501 ds = _dataset_from_backend_dataset(
#     502     backend_ds,
#     503     filename_or_obj,
#    (...)
#     510     **kwargs,
#     511 )
#     512 return ds
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:553, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     532 def open_dataset(
#     533     self,
#     534     filename_or_obj,
#    (...)
#     549     autoclose=False,
#     550 ):
#     552     filename_or_obj = _normalize_path(filename_or_obj)
# --> 553     store = NetCDF4DataStore.open(
#     554         filename_or_obj,
#     555         mode=mode,
#     556         format=format,
#     557         group=group,
#     558         clobber=clobber,
#     559         diskless=diskless,
#     560         persist=persist,
#     561         lock=lock,
#     562         autoclose=autoclose,
#     563     )
#     565     store_entrypoint = StoreBackendEntrypoint()
#     566     with close_on_error(store):
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:382, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     376 kwargs = dict(
#     377     clobber=clobber, diskless=diskless, persist=persist, format=format
#     378 )
#     379 manager = CachingFileManager(
#     380     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     381 )
# --> 382 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:330, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     328 self._group = group
#     329 self._mode = mode
# --> 330 self.format = self.ds.data_model
#     331 self._filename = self.ds.filepath()
#     332 self.is_remote = is_remote_uri(self._filename)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:391, in NetCDF4DataStore.ds(self)
#     389 @property
#     390 def ds(self):
# --> 391     return self._acquire()
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:385, in NetCDF4DataStore._acquire(self, needs_lock)
#     384 def _acquire(self, needs_lock=True):
# --> 385     with self._manager.acquire_context(needs_lock) as root:
#     386         ds = _nc4_require_group(root, self._group, self._mode)
#     387     return ds
#
# File /srv/conda/envs/notebook/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/file_manager.py:187, in CachingFileManager.acquire_context(self, needs_lock)
#     184 @contextlib.contextmanager
#     185 def acquire_context(self, needs_lock=True):
#     186     """Context manager for acquiring a file."""
# --> 187     file, cached = self._acquire_with_cache_info(needs_lock)
#     188     try:
#     189         yield file
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/file_manager.py:205, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     203     kwargs = kwargs.copy()
#     204     kwargs["mode"] = self._mode
# --> 205 file = self._opener(*self._args, **kwargs)
#     206 if self._mode == "w":
#     207     # ensure file doesn't get overridden when opened again
#     208     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2307, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:1925, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/home/jovyan/work/data_share/andrew/data/EC-Earth3-historical.nc'

# %%
data = 'CNRM-CM6-1-historical.nc'
# open the data and re-convert time to cftime so xarray is happy
data_in = xr.open_dataset(f"data/{data}", engine="netcdf4", decode_times=False)#.metpy.quantify()
data_in["tas"] = data_in.tas * units.kelvin
data_in["time"] = cftime.num2date(data_in.time, "minutes since 0000-01-01 00:00:00", calendar="noleap", has_year_zero=True)
data_in["td"] = mpcalc.dewpoint_from_specific_humidity(ps, data_in.tas, data_in.huss)

# %%
spatial_average = data_in.mean(dim=("lat","lon")).dropna(dim="time").chunk({"time":1000})

# %%
# sort the file into 6 groups
the_max = float(spatial_average.mrsos.max().values)
the_min = float(spatial_average.mrsos.min().values)
the_range =  the_max - the_min

spatial_average["soil_moisture_grp"] = ((spatial_average.mrsos / (the_range / 6)).round() * (the_range / 6)).round()

# %%
gbysoil = spatial_average.groupby(spatial_average.soil_moisture_grp)

# %%
gbysoil.groups.keys()
# Out:
# dict_keys([17.0, 26.0, 35.0, 43.0, 52.0, 61.0, 69.0])

# %%
gbysoil[26.0]
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 31656)
# Coordinates:
#   * time               (time) object 0001-11-03 20:27:00 ... 0002-09-30 13:00:00
# Data variables:
#     huss               (time) float32 dask.array<chunksize=(693,), meta=np.ndarray>
#     tas                (time) float32 dask.array<chunksize=(693,), meta=Quantity>
#     mrsos              (time) float32 dask.array<chunksize=(693,), meta=np.ndarray>
#     td                 (time) float32 dask.array<chunksize=(693,), meta=Quantity>
#     soil_moisture_grp  (time) float32 dask.array<chunksize=(693,), meta=np.ndarray>

# %%
hourly_data = gbysoil[26.0].groupby(gbysoil[26.0].time.dt.hour)
hourly_data[9]
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 1406)
# Coordinates:
#   * time               (time) object 0001-11-04 09:00:00 ... 0002-09-30 09:57:00
# Data variables:
#     huss               (time) float32 dask.array<chunksize=(40,), meta=np.ndarray>
#     tas                (time) float32 dask.array<chunksize=(40,), meta=Quantity>
#     mrsos              (time) float32 dask.array<chunksize=(40,), meta=np.ndarray>
#     td                 (time) float32 dask.array<chunksize=(40,), meta=Quantity>
#     soil_moisture_grp  (time) float32 dask.array<chunksize=(40,), meta=np.ndarray>

# %%
# calculate and plot the average diurnal cycle of lcl height
fig, ax = plt.subplots()
for key in gbysoil.groups.keys():
    # group by hour
    hourly_data = gbysoil[key].groupby(gbysoil[key].time.dt.hour).mean(dim="time")  

    # find and plot the lcl
    plcl, tlcl = mpcalc.lcl(ps, hourly_data.tas, hourly_data.td)
    plcl_hpa = plcl / 100
    # HERE should add an hour 24 to each line by copying hour 0

    if key == min(gbysoil.groups.keys()):
        plot_kwargs = {"color":"darkblue"}
    elif key == max(gbysoil.groups.keys()):
        plot_kwargs = {"color":"red"}
    else:
        plot_kwargs = {"color":"black", "linestyle":"--", "linewidth":0.8}

    ax.plot(hourly_data.hour, plcl_hpa[np.isnan(plcl) == False], **plot_kwargs)
    the_label = ax.annotate(f"{round(key)} kg/m$^3$", (24, plcl_hpa[-1]))

# make the plot match Betts fig 11
plt.gca().invert_yaxis()
ax.set_xlabel("UTC")
ax.set_ylabel("P$_{LCL}$ (hPa)")
#ax.axvline(21, color="k", linewidth=1)
ax.xaxis.set_major_locator(MultipleLocator(6))
ax.xaxis.set_major_formatter('{x:.0f}')
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set_xticks((0,6,12,18,24))
ax.set_xlim(0,28)
ax.set_title(data[:-3]);
# Out:
# ---------------------------------------------------------------------------
# OffsetUnitCalculusError                   Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/array/reductions.py:307, in partial_reduce(func, x, split_every, keepdims, dtype, name, reduced_meta)
#     306 try:
# --> 307     meta = func(reduced_meta, computing_meta=True)
#     308 # no meta keyword argument exists for func, and it isn't required
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/array/reductions.py:638, in mean_combine(pairs, sum, numel, dtype, axis, computing_meta, **kwargs)
#     637 ns = deepmap(lambda pair: pair["n"], pairs) if not computing_meta else pairs
# --> 638 n = _concatenate2(ns, axes=axis).sum(axis=axis, **kwargs)
#     640 if computing_meta:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pint/quantity.py:1782, in Quantity._numpy_method_wrap(self, func, *args, **kwargs)
#    1781 elif func.__name__ in op_units_output_ufuncs:
# -> 1782     output_unit = get_op_output_unit(
#    1783         op_units_output_ufuncs[func.__name__],
#    1784         self.units,
#    1785         list(args) + list(kwargs.values()),
#    1786         self._magnitude.size,
#    1787     )
#    1788 else:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pint/numpy_func.py:171, in get_op_output_unit(unit_op, first_input_units, all_args, size)
#     170 if unit_op == "sum":
# --> 171     result_unit = (1 * first_input_units + 1 * first_input_units).units
#     172 elif unit_op == "mul":
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pint/quantity.py:1179, in Quantity.__add__(self, other)
#    1178 else:
# -> 1179     return self._add_sub(other, operator.add)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pint/quantity.py:139, in check_implemented.<locals>.wrapped(self, *args, **kwargs)
#     138     return NotImplemented
# --> 139 return f(self, *args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pint/quantity.py:1155, in Quantity._add_sub(self, other, op)
#    1154 else:
# -> 1155     raise OffsetUnitCalculusError(self._units, other._units)
#    1157 return self.__class__(magnitude, units)
#
# OffsetUnitCalculusError: Ambiguous operation with offset unit (degree_Celsius, degree_Celsius). See https://pint.readthedocs.io/en/latest/nonmult.html for guidance.
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Input In [100], in <cell line: 3>()
#       2 fig, ax = plt.subplots()
#       3 for key in gbysoil.groups.keys():
#       4     # group by hour
# ----> 5     hourly_data = gbysoil[key].groupby(gbysoil[key].time.dt.hour).mean(dim="time")
#       7     # find and plot the lcl
#       8     plcl, tlcl = mpcalc.lcl(ps, hourly_data.tas, hourly_data.td)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/_reductions.py:500, in DatasetGroupByReductions.mean(self, dim, skipna, keep_attrs, **kwargs)
#     420 def mean(
#     421     self: DatasetReduce,
#     422     dim: Union[None, Hashable, Sequence[Hashable]] = None,
#    (...)
#     425     **kwargs,
#     426 ) -> T_Dataset:
#     427     """
#     428     Reduce this Dataset's data by applying ``mean`` along some dimension(s).
#     429
#    (...)
#     498         User guide on groupby operations.
#     499     """
# --> 500     return self.reduce(
#     501         duck_array_ops.mean,
#     502         dim=dim,
#     503         skipna=skipna,
#     504         numeric_only=True,
#     505         keep_attrs=keep_attrs,
#     506         **kwargs,
#     507     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/groupby.py:1021, in DatasetGroupByBase.reduce(self, func, dim, keep_attrs, **kwargs)
#    1017     return ds.reduce(func, dim, keep_attrs, **kwargs)
#    1019 check_reduce_dims(dim, self.dims)
# -> 1021 return self.map(reduce_dataset)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/groupby.py:950, in DatasetGroupByBase.map(self, func, args, shortcut, **kwargs)
#     948 # ignore shortcut if set (for now)
#     949 applied = (func(ds, *args, **kwargs) for ds in self._iter_grouped())
# --> 950 return self._combine(applied)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/groupby.py:970, in DatasetGroupByBase._combine(self, applied)
#     968 def _combine(self, applied):
#     969     """Recombine the applied objects like the original."""
# --> 970     applied_example, applied = peek_at(applied)
#     971     coord, dim, positions = self._infer_concat_args(applied_example)
#     972     combined = concat(applied, dim)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/utils.py:194, in peek_at(iterable)
#     190 """Returns the first value from iterable, as well as a new iterator with
#     191 the same content as the original iterable
#     192 """
#     193 gen = iter(iterable)
# --> 194 peek = next(gen)
#     195 return peek, itertools.chain([peek], gen)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/groupby.py:949, in <genexpr>(.0)
#     919 """Apply a function to each Dataset in the group and concatenate them
#     920 together into a new Dataset.
#     921
#    (...)
#     946     The result of splitting, applying and combining this dataset.
#     947 """
#     948 # ignore shortcut if set (for now)
# --> 949 applied = (func(ds, *args, **kwargs) for ds in self._iter_grouped())
#     950 return self._combine(applied)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/groupby.py:1017, in DatasetGroupByBase.reduce.<locals>.reduce_dataset(ds)
#    1016 def reduce_dataset(ds):
# -> 1017     return ds.reduce(func, dim, keep_attrs, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/dataset.py:5088, in Dataset.reduce(self, func, dim, keep_attrs, keepdims, numeric_only, **kwargs)
#    5083             elif len(reduce_dims) == var.ndim:
#    5084                 # prefer to aggregate over axis=None rather than
#    5085                 # axis=(0, 1) if they will be equivalent, because
#    5086                 # the former is often more efficient
#    5087                 reduce_dims = None  # type: ignore[assignment]
# -> 5088             variables[name] = var.reduce(
#    5089                 func,
#    5090                 dim=reduce_dims,
#    5091                 keep_attrs=keep_attrs,
#    5092                 keepdims=keepdims,
#    5093                 **kwargs,
#    5094             )
#    5096 coord_names = {k for k in self.coords if k in variables}
#    5097 indexes = {k: v for k, v in self.xindexes.items() if k in variables}
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/variable.py:1804, in Variable.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    1800 warnings.filterwarnings(
#    1801     "ignore", r"Mean of empty slice", category=RuntimeWarning
#    1802 )
#    1803 if axis is not None:
# -> 1804     data = func(self.data, axis=axis, **kwargs)
#    1805 else:
#    1806     data = func(self.data, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/duck_array_ops.py:557, in mean(array, axis, skipna, **kwargs)
#     555     return _to_pytimedelta(mean_timedeltas, unit="us") + offset
#     556 else:
# --> 557     return _mean(array, axis=axis, skipna=skipna, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/duck_array_ops.py:335, in _create_nan_agg_method.<locals>.f(values, axis, skipna, **kwargs)
#     333     with warnings.catch_warnings():
#     334         warnings.filterwarnings("ignore", "All-NaN slice encountered")
# --> 335         return func(values, axis=axis, **kwargs)
#     336 except AttributeError:
#     337     if not is_duck_dask_array(values):
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/core/nanops.py:139, in nanmean(a, axis, dtype, out)
#     135 warnings.filterwarnings(
#     136     "ignore", r"Mean of empty slice", category=RuntimeWarning
#     137 )
#     138 if isinstance(a, dask_array_type):
# --> 139     return dask_array.nanmean(a, axis=axis, dtype=dtype)
#     141 return np.nanmean(a, axis=axis, dtype=dtype)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/array/reductions.py:692, in nanmean(a, axis, dtype, keepdims, split_every, out)
#     690 else:
#     691     dt = getattr(np.mean(np.empty(shape=(1,), dtype=a.dtype)), "dtype", object)
# --> 692 return reduction(
#     693     a,
#     694     partial(mean_chunk, sum=chunk.nansum, numel=nannumel),
#     695     mean_agg,
#     696     axis=axis,
#     697     keepdims=keepdims,
#     698     dtype=dt,
#     699     split_every=split_every,
#     700     out=out,
#     701     concatenate=False,
#     702     combine=partial(mean_combine, sum=chunk.nansum, numel=nannumel),
#     703 )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/array/reductions.py:179, in reduction(x, chunk, aggregate, axis, keepdims, dtype, split_every, combine, name, out, concatenate, output_size, meta)
#     176 else:
#     177     reduced_meta = None
# --> 179 result = _tree_reduce(
#     180     tmp,
#     181     aggregate,
#     182     axis,
#     183     keepdims,
#     184     dtype,
#     185     split_every,
#     186     combine,
#     187     name=name,
#     188     concatenate=concatenate,
#     189     reduced_meta=reduced_meta,
#     190 )
#     191 if keepdims and output_size != 1:
#     192     result._chunks = tuple(
#     193         (output_size,) if i in axis else c for i, c in enumerate(tmp.chunks)
#     194     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/array/reductions.py:235, in _tree_reduce(x, aggregate, axis, keepdims, dtype, split_every, combine, name, concatenate, reduced_meta)
#     233     func = compose(func, partial(_concatenate2, axes=sorted(axis)))
#     234 for i in range(depth - 1):
# --> 235     x = partial_reduce(
#     236         func,
#     237         x,
#     238         split_every,
#     239         True,
#     240         dtype=dtype,
#     241         name=(name or funcname(combine or aggregate)) + "-partial",
#     242         reduced_meta=reduced_meta,
#     243     )
#     244 func = partial(aggregate, axis=axis, keepdims=keepdims)
#     245 if concatenate:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/array/reductions.py:311, in partial_reduce(func, x, split_every, keepdims, dtype, name, reduced_meta)
#     309 except TypeError:
#     310     try:
# --> 311         meta = func(reduced_meta)
#     312     except ValueError as e:
#     313         # min/max functions have no identity, don't apply function to meta
#     314         if "zero-size array to reduction operation" in str(e):
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/array/reductions.py:637, in mean_combine(pairs, sum, numel, dtype, axis, computing_meta, **kwargs)
#     634 if not isinstance(pairs, list):
#     635     pairs = [pairs]
# --> 637 ns = deepmap(lambda pair: pair["n"], pairs) if not computing_meta else pairs
#     638 n = _concatenate2(ns, axes=axis).sum(axis=axis, **kwargs)
#     640 if computing_meta:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/utils.py:119, in deepmap(func, *seqs)
#     108 """Apply function inside nested lists
#     109
#     110 >>> inc = lambda x: x + 1
#    (...)
#     116 [[11, 22], [33, 44]]
#     117 """
#     118 if isinstance(seqs[0], (list, Iterator)):
# --> 119     return [deepmap(func, *items) for items in zip(*seqs)]
#     120 else:
#     121     return func(*seqs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/utils.py:119, in <listcomp>(.0)
#     108 """Apply function inside nested lists
#     109
#     110 >>> inc = lambda x: x + 1
#    (...)
#     116 [[11, 22], [33, 44]]
#     117 """
#     118 if isinstance(seqs[0], (list, Iterator)):
# --> 119     return [deepmap(func, *items) for items in zip(*seqs)]
#     120 else:
#     121     return func(*seqs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/utils.py:121, in deepmap(func, *seqs)
#     119     return [deepmap(func, *items) for items in zip(*seqs)]
#     120 else:
# --> 121     return func(*seqs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/dask/array/reductions.py:637, in mean_combine.<locals>.<lambda>(pair)
#     634 if not isinstance(pairs, list):
#     635     pairs = [pairs]
# --> 637 ns = deepmap(lambda pair: pair["n"], pairs) if not computing_meta else pairs
#     638 n = _concatenate2(ns, axes=axis).sum(axis=axis, **kwargs)
#     640 if computing_meta:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pint/quantity.py:1928, in Quantity.__getitem__(self, key)
#    1926 def __getitem__(self, key):
#    1927     try:
# -> 1928         return type(self)(self._magnitude[key], self._units)
#    1929     except PintTypeError:
#    1930         raise
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
