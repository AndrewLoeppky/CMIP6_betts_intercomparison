# %%
import xarray as xr
import pooch
import pandas as pd
import fsspec
from pathlib import Path
import time
import numpy as np
import json
import cftime
import matplotlib.pyplot as plt
import netCDF4 as nc
from cftime import date2num


# Handy metpy tutorial working with xarray:
# https://unidata.github.io/MetPy/latest/tutorials/xarray_tutorial.html#sphx-glr-tutorials-xarray-tutorial-py
import metpy.calc as mpcalc
from metpy.cbook import get_test_data
from metpy.units import units
from metpy.plots import SkewT

# %%
# get esm datastore
odie = pooch.create(
    path="./.cache",
    base_url="https://storage.googleapis.com/cmip6/",
    registry={
        "pangeo-cmip6.csv": None
    },
)
file_path = odie.fetch("pangeo-cmip6.csv")
df_in = pd.read_csv(file_path)

# %%
df_in[df_in.table_id == "3hr"]
# Out:
#         activity_id institution_id        source_id       experiment_id  \
# 27       HighResMIP           MOHC  HadGEM3-GC31-MM  highresSST-present
# 38       HighResMIP           MOHC  HadGEM3-GC31-MM  highresSST-present
# 95       HighResMIP           MOHC  HadGEM3-GC31-HM  highresSST-present
# 96       HighResMIP           MOHC  HadGEM3-GC31-HM  highresSST-present
# 97       HighResMIP           MOHC  HadGEM3-GC31-HM  highresSST-present
# ...             ...            ...              ...                 ...
# 503298         CMIP           CMCC        CMCC-ESM2          historical
# 505089  ScenarioMIP           CMCC        CMCC-ESM2              ssp585
# 505090  ScenarioMIP           CMCC        CMCC-ESM2              ssp585
# 505091  ScenarioMIP           CMCC        CMCC-ESM2              ssp585
# 505092  ScenarioMIP           CMCC        CMCC-ESM2              ssp585
#
#        member_id table_id variable_id grid_label  \
# 27      r1i1p1f1      3hr         prc         gn
# 38      r1i1p1f1      3hr          pr         gn
# 95      r1i1p1f1      3hr         tas         gn
# 96      r1i1p1f1      3hr         prc         gn
# 97      r1i1p1f1      3hr          pr         gn
# ...          ...      ...         ...        ...
# 503298  r1i1p1f1      3hr        huss         gn
# 505089  r1i1p1f1      3hr         vas         gn
# 505090  r1i1p1f1      3hr         uas         gn
# 505091  r1i1p1f1      3hr         tas         gn
# 505092  r1i1p1f1      3hr        huss         gn
#
#                                                    zstore  dcpp_init_year  \
# 27      gs://cmip6/CMIP6/HighResMIP/MOHC/HadGEM3-GC31-...             NaN
# 38      gs://cmip6/CMIP6/HighResMIP/MOHC/HadGEM3-GC31-...             NaN
# 95      gs://cmip6/CMIP6/HighResMIP/MOHC/HadGEM3-GC31-...             NaN
# 96      gs://cmip6/CMIP6/HighResMIP/MOHC/HadGEM3-GC31-...             NaN
# 97      gs://cmip6/CMIP6/HighResMIP/MOHC/HadGEM3-GC31-...             NaN
# ...                                                   ...             ...
# 503298  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 505089  gs://cmip6/CMIP6/ScenarioMIP/CMCC/CMCC-ESM2/ss...             NaN
# 505090  gs://cmip6/CMIP6/ScenarioMIP/CMCC/CMCC-ESM2/ss...             NaN
# 505091  gs://cmip6/CMIP6/ScenarioMIP/CMCC/CMCC-ESM2/ss...             NaN
# 505092  gs://cmip6/CMIP6/ScenarioMIP/CMCC/CMCC-ESM2/ss...             NaN
#
#          version
# 27      20170818
# 38      20170818
# 95      20170831
# 96      20170831
# 97      20170831
# ...          ...
# 503298  20210114
# 505089  20210126
# 505090  20210126
# 505091  20210126
# 505092  20210126
#
# [1941 rows x 11 columns]

# %%
table_id = "3hr"

# %%
correct_table = df_in[df_in.table_id == table_id][df_in.experiment_id == "historical"]
# Out:
# /tmp/ipykernel_9320/3042858839.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   correct_table = df_in[df_in.table_id == table_id][df_in.experiment_id == "historical"]

# %%
correct_table
# Out:
#        activity_id       institution_id          source_id experiment_id  \
# 6238          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 6260          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 6261          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 6276          CMIP            NOAA-GFDL           GFDL-CM4    historical
# 6277          CMIP            NOAA-GFDL           GFDL-CM4    historical
# ...            ...                  ...                ...           ...
# 492709        CMIP  EC-Earth-Consortium  EC-Earth3-AerChem    historical
# 503295        CMIP                 CMCC          CMCC-ESM2    historical
# 503296        CMIP                 CMCC          CMCC-ESM2    historical
# 503297        CMIP                 CMCC          CMCC-ESM2    historical
# 503298        CMIP                 CMCC          CMCC-ESM2    historical
#
#        member_id table_id variable_id grid_label  \
# 6238    r1i1p1f1      3hr        rlus        gr1
# 6260    r1i1p1f1      3hr    rsdsdiff        gr2
# 6261    r1i1p1f1      3hr         tos        gr1
# 6276    r1i1p1f1      3hr         vas        gr2
# 6277    r1i1p1f1      3hr         vas        gr1
# ...          ...      ...         ...        ...
# 492709  r4i1p1f1      3hr         tas         gr
# 503295  r1i1p1f1      3hr         vas         gn
# 503296  r1i1p1f1      3hr         uas         gn
# 503297  r1i1p1f1      3hr         tas         gn
# 503298  r1i1p1f1      3hr        huss         gn
#
#                                                    zstore  dcpp_init_year  \
# 6238    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 6260    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 6261    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 6276    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 6277    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# ...                                                   ...             ...
# 492709  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 503295  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 503296  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 503297  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
# 503298  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-ESM2/historica...             NaN
#
#          version
# 6238    20180701
# 6260    20180701
# 6261    20180701
# 6276    20180701
# 6277    20180701
# ...          ...
# 492709  20201214
# 503295  20210114
# 503296  20210114
# 503297  20210114
# 503298  20210114
#
# [660 rows x 11 columns]

# %%
grouped = correct_table.groupby("source_id")

# %%
grouped.groups.keys()
# Out:
# dict_keys(['ACCESS-CM2', 'ACCESS-ESM1-5', 'AWI-CM-1-1-MR', 'AWI-ESM-1-1-LR', 'BCC-CSM2-MR', 'CMCC-CM2-SR5', 'CMCC-ESM2', 'CNRM-CM6-1', 'CNRM-CM6-1-HR', 'CNRM-ESM2-1', 'CanESM5', 'EC-Earth3', 'EC-Earth3-AerChem', 'EC-Earth3-Veg', 'EC-Earth3-Veg-LR', 'GFDL-CM4', 'GFDL-ESM4', 'GISS-E2-1-G', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'IPSL-CM5A2-INCA', 'IPSL-CM6A-LR', 'KACE-1-0-G', 'KIOST-ESM', 'MIROC-ES2L', 'MIROC6', 'MPI-ESM-1-2-HAM', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR', 'MRI-ESM2-0', 'NESM3', 'SAM0-UNICON', 'TaiESM1', 'UKESM1-0-LL'])
